# %%
from datasets import load_dataset

dataset = load_dataset("wikiann", 'en', cache_dir='/datadisk1/av11/downloads/huggingface')
# Out:
# ...
# Generating train split:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Dataset wikiann downloaded and prepared to /datadisk1/av11/downloads/huggingface/wikiann/en/1.1.0/4bfd4fe4468ab78bb6e096968f61fab7a888f44f9d3371c2f3fea7e74a5a354e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     validation: Dataset({
#         features: ['tokens', 'ner_tags', 'langs', 'spans'],
#         num_rows: 10000
#     })
#     test: Dataset({
#         features: ['tokens', 'ner_tags', 'langs', 'spans'],
#         num_rows: 10000
#     })
#     train: Dataset({
#         features: ['tokens', 'ner_tags', 'langs', 'spans'],
#         num_rows: 20000
#     })
# })

# %%
from src.NERDataSets import tokenize_and_align_labels_wrapper_inside_label

dataset = dataset.map(tokenize_and_align_labels_wrapper_inside_label, batched=True, remove_columns=dataset['train'].column_names)
dataset['train'].set_format('pt')
dataset['validation'].set_format('pt')
dataset['test'].set_format('pt')
dataset
# Out:
# ...
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]
# DatasetDict({
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 20000
#     })
# })

# %%
dataset['validation']['input_ids']
# Out:
# [tensor([    0,   602,    31,  6077, 69944, 40024,    15,   602,    31,  6077,
#          69944,     6,     4, 25134,   930, 38898,  1388,     2]),
#  tensor([    0, 14787, 39643,   929, 11727, 54953, 30541,     6,     4, 89596,
#              6,     5,     2]),
#  tensor([    0,  1657,   206, 26824,     6,     4, 52888,     2]),
#  tensor([    0, 34997, 64330, 86245,  5106,   390, 55331,   538,  6096,  5106,
#          12745, 12610,   329,  5106,   390, 40073, 94598,     2]),
#  tensor([    0,   581, 13547, 86245,     6,     4, 65058,  3003,   372,     6,
#              4,  1773,     5, 64614,     2]),
#  tensor([     0,  40392,     11, 195608,   1681,      9, 176769,   1681,   5106,
#              15, 198387, 162856,   1388,      2]),
#  tensor([    0,   242,  5106, 73223, 71970,  3584,  5106,   242,     2]),
#  tensor([     0,   1529,  36770,    538, 112730,    100,    884,  27613,   6406,
#             136,   5585,   1463,   8287,  14098,      6,      5,      2]),
# ...
